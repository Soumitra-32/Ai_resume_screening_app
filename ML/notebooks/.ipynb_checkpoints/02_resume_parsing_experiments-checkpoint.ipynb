# %%
import sys
sys.path.append("../")

from app.services.resume_parser import (
    extract_text_from_pdf,
    extract_text_from_docx,
    extract_name,
    extract_email,
    extract_phone,
    extract_entities,
)
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.append("../")
# ----> 4 from app.services.resume_parser import (
#       5     extract_text_from_pdf,
#       6     extract_text_from_docx,
#       7     extract_name,
#       8     extract_email,
#       9     extract_phone,
#      10     extract_entities,
#      11 )
#      12 import os
#
# File E:\cse porasuna\ML\Ai-resume-screening\ML\notebooks\..\app\services\resume_parser.py:3
#       1 import re
#       2 import io
# ----> 3 import fitz  # PyMuPDF
#       4 import docx
#       5 from typing import Optional, Tuple, List
#
# ModuleNotFoundError: No module named 'fitz'

# %%
SAMPLE_DIR = "../data/raw"
sample_files = [f for f in os.listdir(SAMPLE_DIR) if f.lower().endswith((".pdf", ".docx"))]
print(f"Found {len(sample_files)} sample resumes")
sample_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 SAMPLE_DIR = "../data/raw"
# ----> 2 sample_files = [f for f in os.listdir(SAMPLE_DIR) if f.lower().endswith((".pdf", ".docx"))]
#       3 print(f"Found {len(sample_files)} sample resumes")
#       4 sample_files
#
# NameError: name 'os' is not defined

# %%
import pandas as pd

results = []

for fname in sample_files:
    path = os.path.join(SAMPLE_DIR, fname)
    with open(path, "rb") as f:
        file_bytes = f.read()

    ext = os.path.splitext(fname)[1].lower()
    try:
        if ext == ".pdf":
            text = extract_text_from_pdf(file_bytes)
        elif ext == ".docx":
            text = extract_text_from_docx(file_bytes)
        else:
            continue

        results.append({
            "filename": fname,
            "text_length": len(text),
            "name": extract_name(text),
            "email": extract_email(text),
            "phone": extract_phone(text),
            "num_entities": len(extract_entities(text)),
        })
    except Exception as e:
        results.append({"filename": fname, "error": str(e)})

df = pd.DataFrame(results)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       3 results = []
# ----> 5 for fname in sample_files:
#       6     path = os.path.join(SAMPLE_DIR, fname)
#       7     with open(path, "rb") as f:
#
# NameError: name 'sample_files' is not defined

# %%
ground_truth = {
    # "resume1.pdf": {"name": "Jane Doe", "email": "jane@example.com", "phone": "555-123-4567"},
}

correct_name = correct_email = correct_phone = 0
total = len(ground_truth)

for fname, truth in ground_truth.items():
    row = df[df["filename"] == fname]
    if row.empty:
        continue
    row = row.iloc[0]
    if row.get("name") == truth.get("name"):
        correct_name += 1
    if row.get("email") == truth.get("email"):
        correct_email += 1
    if row.get("phone") == truth.get("phone"):
        correct_phone += 1

if total:
    print(f"Name accuracy:  {correct_name/total:.0%}")
    print(f"Email accuracy: {correct_email/total:.0%}")
    print(f"Phone accuracy: {correct_phone/total:.0%}")
else:
    print("Add ground_truth entries to measure accuracy.")
# Out:
# Add ground_truth entries to measure accuracy.

# %%
sample = sample_files[0]
path = os.path.join(SAMPLE_DIR, sample)
with open(path, "rb") as f:
    file_bytes = f.read()

ext = os.path.splitext(sample)[1].lower()
text = extract_text_from_pdf(file_bytes) if ext == ".pdf" else extract_text_from_docx(file_bytes)

print(text[:1000])
print("\n--- Entities ---")
for e in extract_entities(text):
    print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sample = sample_files[0]
#       2 path = os.path.join(SAMPLE_DIR, sample)
#       3 with open(path, "rb") as f:
#
# NameError: name 'sample_files' is not defined
